# %% [markdown]
# # atomman.unitconvert.unit
#
# - - -

# %% [markdown]
# **Lucas M. Hale**, [lucas.hale@nist.gov](mailto:lucas.hale@nist.gov?Subject=ipr-demo), *Materials Science and Engineering Division, NIST*.
#
# **Chandler A. Becker**, [chandler.becker@nist.gov](mailto:chandler.becker@nist.gov?Subject=ipr-demo), *Office of Data and Informatics, NIST*.
#
# **Zachary T. Trautt**, [zachary.trautt@nist.gov](mailto:zachary.trautt@nist.gov?Subject=ipr-demo), *Materials Measurement Science Division, NIST*.
#
# Version: 2016-08-23
#
# [Disclaimers](http://www.nist.gov/public_affairs/disclaimer.cfm)
#
# - - -

# %% [markdown]
# ## Introduction
#
# The unit dictionary relates the string names of units to their scaling values. While you can access this directly, it is usually better to use [parse](atomman.unitconvert.parse.ipynb) or one of the conversion functions: [set_in_units](atomman.unitconvert.set_in_units.ipynb), [get_in_units](atomman.unitconvert.get_in_units.ipynb) or [value_unit](atomman.unitconvert.value_unit.ipynb).
#
# The underlying code can be found in [atomman/unitconvert.py](../../atomman/unitconvert.py).

# %% [markdown]
# ## Demonstration

# %%
import atomman.unitconvert as uc

# %% [markdown]
# Default length values are in Angstroms

# %%
print 'angstrom -> ', uc.unit['angstrom']
print 'm        -> ', uc.unit['m']
# Out:
# angstrom ->  1.0
# m        ->  10000000000.0

# %% [markdown]
# List all unit names recognized by unitconvert

# %%
keys = uc.unit.keys()
keys.sort()
for key in keys:
    print key
# Out:
# A
# ARichardson
# Ah
# Angstrom
# C
# Da
# F
# G
# GHz
# GJ
# GL
# GNewton
# GPa
# GV
# GW
# GeV
# Gohm
# Gpc
# H
# Hz
# J
# K
# KJos
# L
# M
# MEarth
# MHz
# MJ
# ML
# MPa
# MV
# MW
# Mbar
# MeV
# Mohm
# Mpc
# Msolar
# N
# NA
# Oe
# PHz
# Pa
# Phi0
# REarth
# RKlitz
# Rgas
# Rinf
# Ry
# S
# T
# THz
# TV
# TW
# TeV
# V
# W
# Wb
# Wh
# Z0
# aBohr
# aF
# aL
# alphaFS
# amu
# angstrom
# astro_unit
# atm
# bar
# btu
# c0
# cbar
# cm
# day
# dbar
# degCinterval
# degFinterval
# dyn
# e
# eV
# eps0
# erg
# fA
# fF
# fJ
# fL
# fM
# fg
# fm
# fmol
# foot
# fs
# g
# g0
# hPa
# hPlanck
# hbar
# hour
# inch
# kB
# kDa
# kG
# kHz
# kJ
# kL
# kPa
# kV
# kW
# kWh
# kbar
# kcal
# keV
# kg
# km
# kohm
# kpc
# lbf
# lbm
# lightyear
# m
# mA
# mAh
# mC
# mG
# mH
# mHz
# mJ
# mL
# mM
# mS
# mT
# mV
# mW
# mbar
# me
# meV
# mg
# mile
# minute
# mm
# mmol
# mn
# mohm
# mol
# mp
# ms
# mtorr
# mu0
# nA
# nC
# nF
# nH
# nJ
# nL
# nM
# nS
# nT
# nV
# nW
# ng
# nm
# nmol
# ns
# ohm
# pA
# pF
# pJ
# pL
# pM
# ...

# %% [markdown]
# - - -
# __Docs Navigation:__
#
# Tutorial:
#
# 1. [Basics](../tutorial/1 Basics.ipynb)
#
# 2. [LAMMPS Functionality](../tutorial/2 LAMMPS Functionality.ipynb)
#
# 3. [Defect Generation and Evaluation](../tutorial/3 Defect Generation and Evaluation.ipynb)
#
#
# Reference:
#
# - [atomman](../reference/atomman.ipynb)
#
# - [atomman.convert](../reference/atomman.convert.ipynb)
#
# - [atomman.defect](../reference/atomman.defect.ipynb)
#
# - [atomman.lammps](../reference/atomman.lammps.ipynb)
#
# - [atomman.tools](../reference/atomman.tools.ipynb)
#
# - [atomman.unitconvert](../reference/atomman.unitconvert.ipynb)
